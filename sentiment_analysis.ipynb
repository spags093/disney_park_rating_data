# %% [markdown]
# # Disney Review Dataset - Sentiment Analysis

# %% [markdown]
# Using NLP methods to explore the reviews in the dataset.  Potentially generate new reviews using the data.

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/spags/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Obtain

# %% [markdown]
# Importing our clean dataset.

# %%
df = pd.read_csv('clean_DisneylandReviews.csv')
df.drop('Unnamed: 0', axis = 1, inplace = True)
print(df.shape)
df.head()
# Out:
# (42656, 6)
#    Rating     Reviewer_Location  \
# 0       4             Australia
# 1       4           Philippines
# 2       4  United Arab Emirates
# 3       4             Australia
# 4       4        United Kingdom
#
#                                          Review_Text               Branch  \
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong
#
#      Year  Month
# 0  2019.0    4.0
# 1  2019.0    5.0
# 2  2019.0    4.0
# 3  2019.0    4.0
# 4  2019.0    4.0

# %% [markdown]
# ## NLP Analysis

# %%
reviews_df = df[['Review_Text', 'Rating']]

# %%
reviews_df.head()
# Out:
#                                          Review_Text  Rating
# 0  If you've ever been to Disneyland anywhere you...       4
# 1  Its been a while since d last time we visit HK...       4
# 2  Thanks God it wasn   t too hot or too humid wh...       4
# 3  HK Disneyland is a great compact park. Unfortu...       4
# 4  the location is not in the city, took around 1...       4

# %% [markdown]
# ### Word Count

# %%
word_count = [len(review.split()) for review in df['Review_Text']]
word_count
# Out:
# [59,
#  171,
#  169,
#  91,
#  31,
#  174,
#  31,
#  101,
#  100,
#  144,
#  42,
#  87,
#  76,
#  22,
#  54,
#  99,
#  47,
#  85,
#  20,
#  44,
#  90,
#  173,
#  146,
#  70,
#  93,
#  40,
#  132,
#  69,
#  59,
#  276,
#  43,
#  110,
#  168,
#  81,
#  551,
#  162,
#  270,
#  164,
#  34,
#  78,
#  44,
#  40,
#  108,
#  48,
#  70,
#  46,
#  117,
#  60,
#  32,
#  24,
#  30,
#  155,
#  56,
#  125,
#  36,
#  28,
#  24,
#  38,
#  62,
#  41,
#  24,
#  201,
#  33,
#  70,
#  89,
#  38,
#  28,
#  66,
#  125,
#  42,
#  34,
#  98,
#  58,
#  51,
#  143,
#  70,
#  56,
#  112,
#  48,
#  166,
#  115,
#  54,
#  91,
#  57,
#  20,
#  152,
#  202,
#  92,
#  24,
#  83,
#  292,
#  61,
#  190,
#  61,
#  35,
#  39,
#  52,
#  27,
#  133,
#  128,
#  91,
#  23,
#  65,
#  135,
#  76,
#  419,
#  85,
#  28,
#  207,
#  84,
#  65,
#  35,
#  63,
#  89,
#  121,
#  75,
#  41,
#  52,
#  29,
#  63,
#  53,
#  108,
#  225,
#  75,
#  251,
#  56,
#  116,
#  43,
#  78,
#  119,
#  113,
#  52,
#  35,
#  74,
#  30,
#  17,
# ...

# %% [markdown]
# ## Pycaret NLP Experiment

# %%
from pycaret.nlp import *
import spacy

# %%
# !pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# /Users/spags/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_core_web_sm' (2.2.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# Set up the data for pycaret
py_data = setup(data = reviews_df, target = 'Review_Text')

# Create model
model = create_model('lsi')

# Assign the model
lsi_df = assign_model(model)
# Out:
# IntProgress(value=0, description='Processing: ', max=42661)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      13:48:08
# Status     . . . . . . . . . . . . . . . . . .  Extracting Topics from Model
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-0e3c025062d7> in <module>
#       6
#       7 # Assign the model
# ----> 8 lsi_df = assign_model(model)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pycaret/nlp.py in assign_model(model, verbose)
#    1726             db_ = model[db]
#    1727             db_array = np.array(db_)
# -> 1728             db_array_ = db_array[:, 1]
#    1729
#    1730             max_ = max(db_array_)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
